# %% [markdown]
# <a href="https://colab.research.google.com/github/Kuoz2/tarea_repositorio/blob/main/FirstHolamundo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pprint import pprint

# %% [markdown]
# # Tarea introduccion a Google Colab y python basic
# **Nombre**:[David Palta]:

# %%
print("Hola mundo!")

# %% [markdown]
# ##Indice 2

# %%
a = 10
b = 20
suma = a + b
print('La suma entre a y b es: ', suma)
# Out:
# La suma entre a y b es:  30

# %% [markdown]
# #Defincion de funciones en Colab

# %%
# Se defin el
def sumar(x, y):
  return x + y

resultado1 = sumar(5, 7)
print(f"La suma de la funcion sumar es: {resultado1}")

resultado2 = sumar(20, 30)
print("La segunda suma de la funcion sumar es: ", resultado2)
# Out:
# La suma de la funcion sumar es: 12
# La segunda suma de la funcion sumar es:  50

# %% [markdown]
# #Uso de pprint y sus cualidades

# %%
datos = {
    "nombre":"juan",
    "edad": 30,
    "hobbies": ["leer", "correr", "programar"],
    "educacion":{
        "primaria": "Escuela A",
        "secundaria": "Escuela B",
        "universidad": "Universidad C"
    }
}
print("---Print normal---")
print(datos)
print("---PRINT CON PPRINT---")
pprint(datos)
print("---PPRINT Y AJUSTES DE TAMAÑO---")
pprint(datos, width=40, depth= 2 )
# Out:
# ---Print normal---
# {'nombre': 'juan', 'edad': 30, 'hobbies': ['leer', 'correr', 'programar'], 'educacion': {'primaria': 'Escuela A', 'secundaria': 'Escuela B', 'universidad': 'Universidad C'}}
# ---PRINT CON PPRINT---
# {'edad': 30,
#  'educacion': {'primaria': 'Escuela A',
#                'secundaria': 'Escuela B',
#                'universidad': 'Universidad C'},
#  'hobbies': ['leer', 'correr', 'programar'],
#  'nombre': 'juan'}
# ---PPRINT Y AJUSTES DE TAMAÑO---
# {'edad': 30,
#  'educacion': {'primaria': 'Escuela A',
#                'secundaria': 'Escuela '
#                              'B',
#                'universidad': 'Universidad '
#                               'C'},
#  'hobbies': ['leer',
#              'correr',
#              'programar'],
#  'nombre': 'juan'}

# %% [markdown]
# #Probando las cajas de ingreso de informacion INPUT

# %%
nombre = input("¿Cúal es tu nombre? ")
print(f"Hola, {nombre}!")

# %% [markdown]
# ##Conversion de tipos

# %%
edad = input("¿Cúal años tienes?")
edad = int(edad) #Convierte los datos en números enteros.
print(f"Tiene {edad} años")

# %% [markdown]
# ###El uso de try al detectar que no se puede ejecutar por alguna razon

# %%
try:
  edad = int(input("¿Cuantos años tienes?"))
  print(f"Tienes {edad} años.")
except ValueError:
  print("Porfavor ingrese un numero valido")

# %% [markdown]
# # Nueva sección

# %% [markdown]
# #Métodos de Cadenas

# %%
#1. Upper y lowe
texto = "Hola Mundo"
print(texto.upper())  # "HOLA MUNDO"
print(texto.lower())  # "hola mundo"
#2. len
print(len(texto))  # 10
texto = "   Hola Mundo   "
#3. strip, lstrip y rstrip
print(texto.strip())   # "Hola Mundo"
print(texto.lstrip())  # "Hola Mundo   "
print(texto.rstrip())  # "   Hola Mundo"
#4. split
texto = "Hola, Mundo, Python"
lista = texto.split(", ")  # ['Hola', 'Mundo', 'Python']
print(lista)
nuevo_texto = " ".join(lista)
print(nuevo_texto)  # "Hola Mundo Python"
#5. replace
texto = "Hola Mundo"
nuevo_texto = texto.replace("Mundo", "Python")
print(nuevo_texto)  # "Hola Python"
#6. find, index
texto = "Hola Mundo"
print(texto.find("Mundo"))  # 5
print(texto.index("Mundo"))  # 5
#7. startswith, endswith
texto = "Hola Mundo"
print(texto.startswith("Hola"))  # True
print(texto.endswith("Mundo"))  # True
#8. count
texto = "Hola Mundo Hola"
print(texto.count("Hola"))  # 2
# Out:
# HOLA MUNDO
# hola mundo
# 10
# Hola Mundo
# Hola Mundo
#    Hola Mundo
# ['Hola', 'Mundo', 'Python']
# Hola Mundo Python
# Hola Python
# 5
# 5
# True
# True
# 2
